# %% [markdown]
# # HW01: TF-IDF
# 自行設定一個 query，在搜尋引擎上搜尋，取前三篇文章(不包括 _廣告_ )‧計算 3 documents 中，tf-idf 分數最高的 top-5，獲取“關鍵字” The problems that you may encounter:
#
# 如何存資料、在那裡做計算、如何產生
#
# * output
# * 斷字: Jieba (pip install jieba) jieba.cut
# * (key, value)

# %% [markdown]
# > Written by 111755001 應物碩一 張淮竣
# >
# > Github: [harui2019](https://github.com/harui2019) - You may find this jupyter noebook in my repositories.

# %% [markdown]
# ## Env. and Data Preparation

# %%
import jieba
import numpy as np
from collections import Counter

# %%
ShoheiOhtani = [
    '大谷連續12場敲安！創生涯新高 天使隊二刀流好手大谷翔平今天在對戰運動家隊比賽，不但敲出生涯最多的連續12場安打，他也完成單季150支安打的紀錄。這是大谷二刀流球季單季最多勝投，目前已經累積14勝，安打部分，今年150支安打，投球局數153，三振203次，投打都超過150。大谷這場打三棒、指定打擊，他在首局2人出局狀況，敲出中外野直擊全壘打牆二壘安打，可惜無法幫球隊打下分數。',
    'MLB》大谷翔平連12戰敲安創新高！ 再締史上首見二刀流紀錄 〔體育中心／綜合報導〕天使隊大谷翔平今天在與運動家一戰，首打席就敲出安打，將自己生涯最長的連續安打場次改寫為12場，同時也締造大聯盟史上首見的二刀流紀錄。大谷翔平首打席面對運動家先發卡普里耶利安（James Kaprielian）就敲出二壘安打，連續12場敲安創生涯最佳紀錄，他的打擊率也在這段期間從2成65提升到2成73。該支二壘安打是大谷翔平本季第29支二壘安打，同時也是本季第150支安打，根據日媒《Sponichi Annexi》指出，大谷翔平在本季敲出150安（151安），投手方面上投球150局（153局）、150K（203K）以上，三項指標紀錄都能達標150，是自1900年現代棒球以來史上首見的紀錄。本季大谷翔平繳出僅次去年的生涯次佳打擊表現，目前已經敲出93分打點的他，有機會在本季再度達標100分打點，成為自2004、2005年的松井秀喜以來，第一位連續2季百打點的日本人選手。大谷翔平今天4打數2安打，打擊率提升到2成73，天使8下靠著阿德爾（Jo Adell）打進超前分，終場以4：3擊敗運動家。',
    'MLB》大谷翔平連12場安打寫新高 被牽制回壘遲不起身還偷笑 天使主場迎戰運動家的比賽，日籍「二刀流」好手大谷翔平今日擔綱3棒指定打擊，4個打數當中敲出2支安打，連續12場比賽有安打演出，寫下大聯盟生涯新高，另外大谷翔平本季安打數來到151支，成為第6位寫下單季150安紀錄的日本球員。 生涯對決運動家先發投手卡普瑞利安(James Kaprielian)，大谷翔平12個打數僅有1支安打，還吞下5張老K，對戰打擊率不到1成，今日大谷翔平終於找到機會雪恥，首打席2人出局情況下，逮中1顆95.7英里沉球，將球推向中左外野方向大空檔，形成一支二壘安打，只不過隊友無法將大谷翔平送回。3局下大谷翔平第2打席還是面對卡普瑞利安，再次擊出左外野方向安打上壘。有趣的是當卡普瑞利安牽制一壘時，選擇以撲壘方式回到壘包的大谷翔平，就算一壘審已做出安全回壘的宣判，依然趴在地上好一段時間才肯起身，又一次把大聯盟當成個人表演舞台的大谷翔平，臉上也藏不住笑意。 大谷翔平最後2個打席分別以滾地球及三振出局，總計他4個打數敲出2安，吞下1次三振。天使在8局下半靠著艾戴爾(Jo Adell)安打突破平手僵局，最終天使以4：3拿下勝利。本場擊出雙安的大谷翔平，也完成了連續12場有安打的演出，寫下大聯盟生涯最佳，同時大谷翔平也成為自鈴木一朗、松井秀喜、井口資仁、岩村明憲、青木宣親後，第6位完成單季150安的日本球員。',
    '傳奇球星認証！大谷完全沒有弱點 天使隊日籍二刀流好手大谷翔平本季14勝，防禦率2.47，203次奪三振，打者部分2成71打擊率，34轟，93打點，對於大谷的表現，生涯累積3053支安打的傳奇球星Rod Carew也認為「大谷沒有弱點」。 大谷的表現驚人，讓Rod Carew評論：「他表現太出色，尤其是他的跑壘，總是全力衝刺，讓我想到Derek Jeter、Mike Trout等人。」「他好像沒什麼弱點，過去他會後腳離地，但現在看他重心留得很好，並沒有身體開掉的狀況。」他說。Rod Carew也稱讚大谷是「很危險、很危險的打者，他可以輕鬆把球打到右外野、中外野等，是很難讓他出局的選手。」', 
    '大谷絕叫！自打球表情好痛苦 天使隊二刀流好手大谷翔平今天在對戰運動家隊比賽，不但敲出生涯最多的連續12場安打，他也完成單季150支安打的紀錄，不過大谷在7局因為自打球，一度大叫，並且露出痛苦表情，天使最終以4:3贏球。大谷今天4打數2安打，7局他面對CYR，自打球打中他的右腳，大谷忍不住大叫，並且露出痛苦神情。最後大谷在這一打席被三振，但是大谷之後比賽是否受到影響，還需要觀察。大谷在首打席敲出二壘安打，第二打席又敲出左外野安打上壘，打擊率升為2成73。',
    'MLB／翻譯水原一平爆料 大谷翔平迷上影集「怪奇物語」 天使球星大谷翔平與他的翻譯水原一平關係向來很要好，水原一平透過《體育日本》專欄，介紹大谷翔平的場外故事，並透露大谷私下稱讚「法官」賈吉（Aaron Judge）：「好厲害啊，真是異次元的」。水原一平在專欄中透露，大谷翔平最近迷上Netflix的影集《怪奇物語》，而且1到4季都看完了，水原說：「他還跟我推薦，說很有趣，一定要看。」大谷日前達成200K，捕手也把球交給水原。大谷向來對於達成紀錄的紀念物不感興趣，不過這次卻意外地將那顆球收進置物櫃裡。大谷翔平達成200K紀錄的那天，他的前隊友、紅雀普荷斯（Albert Pujols）也擊出雙響砲完成700轟，眼尖的大谷發現被擊出699轟的是也在天使同隊過的左投希尼（Andrew Heaney）並說到：「啊，是希尼啊！」同時大谷也為普荷斯達成紀錄感到高興。水原還提到，天使休息室的電視常常播出MVP競爭對手賈吉的比賽畫面，大谷也經常表示讚嘆：「好厲害啊，真是異次元的。」',
    '賈吉、大谷翔平看好誰？ 7百轟「普神」心中有答案：打出難以置信的賽季 紐約洋基「法官」賈吉（Aaron Judge）與洛杉磯天使二刀流大谷翔平的美聯MVP之爭，是季後備受矚目的焦點，大家心裡總是有自己想力挺的球員；對此，先前才打出生涯700轟里程碑的普荷斯（Albert Pujols）也發表了自身的看法。 在今天之前，賈吉繳出3成14打擊率、60轟、128分打點的成績單，OPS值高達可怕的1.117，另外選到106次保送，這些數據都在美聯排名第一；至於大谷翔平，他在打擊上繳出2成71打擊率、34轟、93分打點以及11次盜壘的表現，投球方面，他累積14勝8敗、防禦率2.47的成績，153局的投球飆出203次三振。事實上，賈吉跟大谷翔平今年的表現，如果不要出現在同一年，都會是MVP的最佳人選，不過一年只會出現一個美聯MVP，相信季後在進行票選時，棒球作家協會的成員們會難以做出抉擇。正當各個球員、教練甚至是媒體，都表態自己的力挺對象，普荷斯日前受訪時也分享自己的看法，他說：「事實就是，賈吉的賽季令人難以置信，我為他感到非常高興，我希望他打破美聯全壘打紀錄，而他會做到的，還有很多場比賽。」他認為，賈吉無疑會是今年的美聯MVP人選。',
    '大谷翔平連12場安創新高！3個「150」寫二刀流另一成就 天使隊日籍「二刀流」球星大谷翔平今天對運動家之戰，首打席就敲出安打，連續安打場次推進至12場，創生涯新高，同時達成單季150支安打，寫下「二刀流」另一成就。大谷翔平今天先發第3棒指定打擊，1局下面對運動家先發投手普里耶利安（James Kaprielian），掃出二壘長打，連續12場安打為個人最佳紀錄。值得一提的是，大谷翔平這一安，剛好是今年的第150安，投球方面累計至少150局、150K（203K），達成3個「150」，是自1900年現代棒球以來，史上第一人。大谷翔平3局下第二打席再敲出安打，接下來2打席都出局，分別擊出滾地球、吞下三振；此役4打數2安打，打擊率升至0.273。運動家在2局上攻下3分先馳得點，2局下，天使反攻追回3分扳平比數。8局下，艾德爾（Jo Adell）壘上有人適時安打，攻下致勝分，率天使4比3逆轉，取得2連勝。',
    'MLB》60轟後沒球打！ 洋基「法官」生涯第二度單場4保送 〔體育中心／綜合報導〕洋基隊今日在主場以5：2擊敗藍鳥，在美聯東區封王，而眾所矚目的「法官」賈吉（Aaron Judge）獲得4次四壞保送上壘，目前仍維持三冠王頭銜。賈吉此役打擊成績為1打數0安打，共獲得4次四壞保送上壘，賈吉今日5次上場打擊，對手都投得相當小心，他今天共面對33球僅有14顆好球（包含他打的界外球），這也是他生涯第二次單場4度獲得四壞保送的比賽，本月賈吉一共獲得26次保送，僅次於自己在2017年9月獲得的單月28次保送。賈吉在明星賽後一共獲得60次的四壞保送，追平生涯次高，他在2017年明星賽後一共獲得66次四壞保送，而洋基在明星賽後能獲得這麼多保送的球員，自分區年代以來僅有2005年的吉昂比（Jason Giambi），當年他明星賽後獲得64次四壞保送。根據數據指出，賈吉在敲出60轟後，他31個打席就獲得12次的四壞保送，平均每2.6個打席就會被保送上壘一次，而他獲得的壞球比則是36.7%，上壘率高達5成33。藍鳥本場比賽雖然在「春天哥」史普林格（George Springer）首局首打席開轟先馳得點，不過後續在守備與跑壘上都發生瑕疵，於3上遭洋基超前後就一去不復返，藍鳥終場也以2：5輸球。',
    'MLB／美聯MVP之爭 大谷前隊友普荷斯票投賈吉 今年大聯盟美聯MVP之爭的話題圍繞在大谷翔平與賈吉（Aaron Judge）身上，曾是大谷隊友的普荷斯（Albert Pujols），在接受ESPN採訪時透露自己的心意，「賈吉是MVP，無庸置疑」。普荷斯曾在2013到2021年效力於天使隊，去年季中轉戰道奇，今年球季回到生涯起點的紅雀隊，趕在退休之前，達成生涯第700轟的里程碑。在MVP的討論上，普荷斯更肯定賈吉的成績，「事實上，賈吉今年的表現太不可思議。」賈吉已敲出60發全壘打，距離美聯紀錄只差1轟，「我希望他能達成，我會很為他開心，還有很多比賽可以挑戰。」要說MVP人選，普荷斯認為大谷翔平、拉米瑞茲（Jose Ramirez）、楚奧特（Mike Trout）確實也有MVP等級的身手，但他認為美聯MVP還是屬於賈吉，「這點無庸置疑，祝他好運，我很早就覺得他是MVP。」',
    'MLB／賈吉被連保送4次沒好球打 洋基還是贏球奪美東王座 賈吉（Aaron Judge）今天沒好球可打，面對藍鳥隊單場獲得4次保送，然而洋基隊還是有其他人跳出來，托瑞斯（Gleyber Torres）3安、3分打點演出，幫助洋基隊以5：2拿下勝利，提前慶祝美聯東區封王。賈吉今天打第一棒，首打席敲出三壘飛球出局，然而後面藍鳥投手沒有讓他有太多好球可打，連4個打席都獲得四壞保送，這是他生涯第二次遭遇此等「禮遇」，總計1打數無安打、4次保送，打擊率為3成14，還是保有美聯打擊三冠王頭銜。沒有投手想當61轟的苦主，賈吉自從9月21日敲出本季第60轟後，已經熄火7場，這段期間一共獲得12次四壞保送，外加1次故意四壞保送，總教練布恩（Aaron Boone）表示，賈吉還是能夠保持自己的本壘板紀律，選出好球、維持擊球的品質。即使賈吉沒辦法用球棒建功，但仍跑回2分，靠得是隊友安打串連，藍鳥隊雖然在1局下就由史普林格（George Springer）的首局首打席全壘打先馳得點，不過3局上賈吉被保送後，瑞佐（Anthony Rizzo）、托瑞斯的兩支安打各有1分打點，超前比數。洋基後續不斷追加分數，而先發投手泰隆（Jameson Taillon）7.1局投球雖被敲出7支安打，但僅失2分，另有6次三振、沒有保送，拿下本季第14勝。洋基隊這一勝讓藍鳥隊的淘汰指數直接歸零，也代表提前確定收下美聯東區第一名的頭銜，這是隊史第20次在分區封王，前一次是2019年。',
    '大谷翔平繳4支2成績 連12場比賽有安打創生涯新高【MLB亞洲球星精華】奧克蘭運動家與洛杉磯天使的系列賽首戰，天使日籍好手大谷翔平擔任指定打擊第3棒，並繳出4支2、吞1K成績，同時創下連12場有安打的生涯新高紀錄，打擊率也上升至0.273，終場天使也以4比3擊敗運動家。'
]

ppap_all = '''
I have a pen 
I have an apple 
Ugh 
Apple pen 

I have a pen 
I have pineapple 
Ugh 
Pineapple pen 

Apple pen 
Pineapple pen 

Ugh 
Pen Pineapple Apple Pen 

Pen Pineapple Apple Pen
'''

# %% [markdown]
# #### `jieba.cut` demo

# %%
afterJiebaShoheiOhtani = [
    [t for t in jieba.cut(txt)] for txt in ShoheiOhtani
]

print(afterJiebaShoheiOhtani[0])
# Out:
# ['大谷', '連續', '12', '場敲安', '！', '創', '生涯', '新高', ' ', '天使', '隊二刀流', '好手', '大谷', '翔平', '今天', '在', '對', '戰運動家隊', '比賽', '，', '不但', '敲出', '生涯', '最多', '的', '連續', '12', '場安打', '，', '他', '也', '完成', '單季', '150', '支安打', '的', '紀錄', '。', '這是', '大谷', '二刀流', '球季', '單季', '最多勝', '投', '，', '目前', '已經', '累積', '14', '勝', '，', '安', '打', '部分', '，', '今年', '150', '支安打', '，', '投球', '局數', '153', '，', '三振', '203', '次', '，', '投打', '都', '超過', '150', '。', '大谷', '這場', '打三棒', '、', '指定', '打擊', '，', '他', '在', '首局', '2', '人', '出局', '狀況', '，', '敲出', '中外', '野直擊', '全壘', '打牆', '二壘', '安打', '，', '可惜', '無法', '幫球隊', '打下', '分數', '。']

# %% [markdown]
# #### `jieba.lcut` demo

# %%
afterJiebaL = [
    [t for t in jieba.lcut(txt)] for txt in ShoheiOhtani
]

print(afterJiebaL[0])
# Out:
# ['大谷', '連續', '12', '場敲安', '！', '創', '生涯', '新高', ' ', '天使', '隊二刀流', '好手', '大谷', '翔平', '今天', '在', '對', '戰運動家隊', '比賽', '，', '不但', '敲出', '生涯', '最多', '的', '連續', '12', '場安打', '，', '他', '也', '完成', '單季', '150', '支安打', '的', '紀錄', '。', '這是', '大谷', '二刀流', '球季', '單季', '最多勝', '投', '，', '目前', '已經', '累積', '14', '勝', '，', '安', '打', '部分', '，', '今年', '150', '支安打', '，', '投球', '局數', '153', '，', '三振', '203', '次', '，', '投打', '都', '超過', '150', '。', '大谷', '這場', '打三棒', '、', '指定', '打擊', '，', '他', '在', '首局', '2', '人', '出局', '狀況', '，', '敲出', '中外', '野直擊', '全壘', '打牆', '二壘', '安打', '，', '可惜', '無法', '幫球隊', '打下', '分數', '。']

# %%
path = 'userDict.txt'
userDict = []
with open(path) as f:
    lines = f.readlines()
    for line in lines:
        userDict.append(line.replace('\n', ''))

print(userDict)

jieba.load_userdict('userDict.txt')
# Out:
# ['大谷', '翔平', '大谷翔平', '鈴木一朗', '鈴木', '一朗', '松井秀喜', '松井', '秀喜', '井口資仁', '井口', '資仁', '岩村明憲', '岩村', '明憲', '青木宣親', '青木', '宣親', '二刀流', '普荷斯', 'Albert Pujols', '賈吉', 'Aaron Judge', '水原一平', '天使隊', '道奇', '道奇隊', '運動家', '運動家隊', '紅雀', '紅雀隊', '拉米瑞茲', 'Jose Ramirez', '楚奧特', 'Mike Trout']

# %%
afterJiebaL = [
    [t for t in jieba.lcut(txt)] for txt in ShoheiOhtani
]

print(afterJiebaL[0])
# Out:
# ['大谷', '連續', '12', '場敲安', '！', '創', '生涯', '新高', ' ', '天使隊', '二刀流', '好手', '大谷翔平', '今天', '在', '對戰', '運動家隊', '比賽', '，', '不但', '敲出', '生涯', '最多', '的', '連續', '12', '場安打', '，', '他', '也', '完成', '單季', '150', '支安打', '的', '紀錄', '。', '這是', '大谷', '二刀流', '球季', '單季', '最多勝', '投', '，', '目前', '已經', '累積', '14', '勝', '，', '安', '打', '部分', '，', '今年', '150', '支安打', '，', '投球', '局數', '153', '，', '三振', '203', '次', '，', '投打', '都', '超過', '150', '。', '大谷', '這場', '打三棒', '、', '指定', '打擊', '，', '他', '在', '首局', '2', '人', '出局', '狀況', '，', '敲出', '中外', '野直擊', '全壘', '打牆', '二壘', '安打', '，', '可惜', '無法', '幫球隊', '打下', '分數', '。']

# %% [markdown]
# ### 詞性辨識
#
# - Ref: https://www.cnblogs.com/chenbjin/p/4341930.html
# - Ref: https://blog.pulipuli.info/2017/11/fasttag-identify-part-of-speech-in.html

# %%
import jieba.posseg as pseg
jieba.load_userdict('userDict.txt')
withPossegL = [
    [(t, f) for t, f in pseg.lcut(txt)] for txt in ShoheiOhtani
]

# %%
print(withPossegL[0])
# Out:
# [('大谷', 'n'), ('連續', 'a'), ('12', 'm'), ('場', 'q'), ('敲', 'v'), ('安', 'v'), ('！', 'x'), ('創', 'x'), ('生涯', 'n'), ('新高', 'v'), (' ', 'x'), ('天使隊', 'x'), ('二刀流', 'x'), ('好手', 'v'), ('大谷翔平', 'x'), ('今天', 't'), ('在', 'p'), ('對', 'p'), ('戰', 'n'), ('運動家隊', 'x'), ('比賽', 'vn'), ('，', 'x'), ('不但', 'c'), ('敲出', 'v'), ('生涯', 'n'), ('最多', 'a'), ('的', 'uj'), ('連續', 'a'), ('12', 'm'), ('場安', 'n'), ('打', 'v'), ('，', 'x'), ('他', 'r'), ('也', 'd'), ('完成', 'v'), ('單季', 'n'), ('150', 'm'), ('支安', 'nr'), ('打', 'v'), ('的', 'uj'), ('紀錄', 'n'), ('。', 'x'), ('這', 'r'), ('是', 'v'), ('大谷', 'n'), ('二刀流', 'x'), ('球季', 'n'), ('單季', 'n'), ('最多', 'd'), ('勝', 'v'), ('投', 'vn'), ('，', 'x'), ('目前', 't'), ('已經', 'd'), ('累積', 'v'), ('14', 'm'), ('勝', 'vn'), ('，', 'x'), ('安', 'v'), ('打', 'v'), ('部分', 'n'), ('，', 'x'), ('今年', 't'), ('150', 'm'), ('支安', 'n'), ('打', 'v'), ('，', 'x'), ('投球', 'n'), ('局數', 'n'), ('153', 'm'), ('，', 'x'), ('三振', 'n'), ('203', 'm'), ('次', 't'), ('，', 'x'), ('投打', 'v'), ('都', 'd'), ('超過', 'v'), 
# ...

# %% [markdown]
# ### TF-IDF
# $$\text{tf-idf}(t, d, D) = \text{tf}(t, d) ⋅ \text{idf}(t, D)$$

# %% [markdown]
# ####  TF: Term frequency(字頻)
#
# TF is the relative frequency of term $t$ within document $d$
# $$\text{tf}(t,d) = \frac{f_{t,d}}{\sum_{t'\in d}f_{t',d}} $$
# where $f_{t,d}$ is the raw count of a term in a document.

# %% [markdown]
# #### IDF: Inverse document frequency
#
# $$\text{idf}(t, D) = \log\frac{N}{|\{d\in D : t\in d\}|}$$
# where $N$: total number of documents in the corpus $N = |D|$
#
# and $|\{d\in D : t\in d\}|$: number of documents where the term t appears

# %%
ppap_lines = ppap_all.split('\n')
ppap_lines = [sentence for sentence in ppap_lines if len(sentence) > 0]
ppap_lyrics = []
for line in ppap_lines:
    for w in line.split(' '):
        if len(w) > 0:
            ppap_lyrics.append(w)
print(ppap_lyrics)
print('-'*30)
print(Counter(ppap_lyrics))
# Out:
# ['I', 'have', 'a', 'pen', 'I', 'have', 'an', 'apple', 'Ugh', 'Apple', 'pen', 'I', 'have', 'a', 'pen', 'I', 'have', 'pineapple', 'Ugh', 'Pineapple', 'pen', 'Apple', 'pen', 'Pineapple', 'pen', 'Ugh', 'Pen', 'Pineapple', 'Apple', 'Pen', 'Pen', 'Pineapple', 'Apple', 'Pen']
# ------------------------------
# Counter({'pen': 6, 'I': 4, 'have': 4, 'Apple': 4, 'Pineapple': 4, 'Pen': 4, 'Ugh': 3, 'a': 2, 'an': 1, 'apple': 1, 'pineapple': 1})

# %%
jieba.load_userdict('userDict.txt')
withPossegL = [
    [
        (t, f) for t, f in pseg.lcut(txt) if f not in [
            'x', 'eng', 'w', 'm', 'ud', 'uj', 'uv', 'ug', 'ul', 'uz', 'g'
        ]
    ] for txt in ShoheiOhtani
]

# %%
print(withPossegL[0])
# Out:
# [('大谷', 'n'), ('連續', 'a'), ('場', 'q'), ('敲', 'v'), ('安', 'v'), ('生涯', 'n'), ('新高', 'v'), ('好手', 'v'), ('今天', 't'), ('在', 'p'), ('對', 'p'), ('戰', 'n'), ('比賽', 'vn'), ('不但', 'c'), ('敲出', 'v'), ('生涯', 'n'), ('最多', 'a'), ('連續', 'a'), ('場安', 'n'), ('打', 'v'), ('他', 'r'), ('也', 'd'), ('完成', 'v'), ('單季', 'n'), ('支安', 'nr'), ('打', 'v'), ('紀錄', 'n'), ('這', 'r'), ('是', 'v'), ('大谷', 'n'), ('球季', 'n'), ('單季', 'n'), ('最多', 'd'), ('勝', 'v'), ('投', 'vn'), ('目前', 't'), ('已經', 'd'), ('累積', 'v'), ('勝', 'vn'), ('安', 'v'), ('打', 'v'), ('部分', 'n'), ('今年', 't'), ('支安', 'n'), ('打', 'v'), ('投球', 'n'), ('局數', 'n'), ('三振', 'n'), ('次', 't'), ('投打', 'v'), ('都', 'd'), ('超過', 'v'), ('大谷', 'n'), ('這場', 'mq'), ('打', 'v'), ('棒', 'a'), ('指定', 'v'), ('打擊', 'v'), ('他', 'r'), ('在', 'p'), ('首局', 'n'), ('人', 'n'), ('出局', 'n'), ('狀況', 'n'), ('敲出', 'v'), ('中外', 'f'), ('野', 'b'), ('直擊', 'v'), ('全壘', 'n'), ('打', 'v'), ('牆', 'n'), ('二壘', 'n'), ('安打', 'v'), ('可惜', 'v'), ('無法', 'b'), ('幫球隊', 'n'), ('打下', 'v'), ('分數', 'n')]

# %%
withPossegLTF = [
    Counter([w for w, f in v])
for v in withPossegL]

withPossegLTF = [
    { w: t/sum(v.values()) for w, t in v.items() }
for v in withPossegLTF]

print(withPossegLTF[0])
# Out:
# {'大谷': 0.038461538461538464, '連續': 0.02564102564102564, '場': 0.01282051282051282, '敲': 0.01282051282051282, '安': 0.02564102564102564, '生涯': 0.02564102564102564, '新高': 0.01282051282051282, '好手': 0.01282051282051282, '今天': 0.01282051282051282, '在': 0.02564102564102564, '對': 0.01282051282051282, '戰': 0.01282051282051282, '比賽': 0.01282051282051282, '不但': 0.01282051282051282, '敲出': 0.02564102564102564, '最多': 0.02564102564102564, '場安': 0.01282051282051282, '打': 0.07692307692307693, '他': 0.02564102564102564, '也': 0.01282051282051282, '完成': 0.01282051282051282, '單季': 0.02564102564102564, '支安': 0.02564102564102564, '紀錄': 0.01282051282051282, '這': 0.01282051282051282, '是': 0.01282051282051282, '球季': 0.01282051282051282, '勝': 0.02564102564102564, '投': 0.01282051282051282, '目前': 0.01282051282051282, '已經': 0.01282051282051282, '累積': 0.01282051282051282, '部分': 0.01282051282051282, '今年': 0.01282051282051282, '投球': 0.01282051282051282, '局數': 0.01282051282051282, '三振': 0.01282051282051282, '次': 0.012
# ...

# %%
withPossegLIDF = {}
for art in withPossegLTF:
    for w in art:
        if w not in withPossegLIDF:
            withPossegLIDF[w] = 0
        withPossegLIDF[w] += 1

withPossegLIDF = {
    w: np.log(len(withPossegLTF)/t) for w, t in withPossegLIDF.items()
}
print(withPossegLIDF)
# Out:
# {'大谷': 0.8754687373538999, '連續': 0.8754687373538999, '場': 0.5389965007326869, '敲': 1.791759469228055, '安': 0.8754687373538999, '生涯': 0.0870113769896297, '新高': 0.8754687373538999, '好手': 0.8754687373538999, '今天': 0.5389965007326869, '在': 0.1823215567939546, '對': 0.4054651081081644, '戰': 1.0986122886681098, '比賽': 0.4054651081081644, '不但': 1.791759469228055, '敲出': 0.4054651081081644, '最多': 1.791759469228055, '場安': 1.0986122886681098, '打': 0.1823215567939546, '他': 0.1823215567939546, '也': 0.0870113769896297, '完成': 1.0986122886681098, '單季': 1.0986122886681098, '支安': 0.5389965007326869, '紀錄': 0.5389965007326869, '這': 0.6931471805599453, '是': 0.1823215567939546, '球季': 1.791759469228055, '勝': 1.0986122886681098, '投': 1.3862943611198906, '目前': 1.3862943611198906, '已經': 1.3862943611198906, '累積': 1.3862943611198906, '部分': 1.791759469228055, '今年': 1.0986122886681098, '投球': 0.8754687373538999, '局數': 2.4849066497880004, '三振': 0.5389965007326869, '次': 0.8754687373538999, '投打': 2.4849066497880004, '都
# ...

# %%
withPossegL_TF_IDF = {}
for i, art in enumerate(withPossegLTF):
    withPossegL_TF_IDF[i] = {}
    for w in art:
        withPossegL_TF_IDF[i][w] = art[w] * withPossegLIDF[w]

# %% [markdown]
# 每一篇文章的TF-IDF

# %%
print(withPossegL_TF_IDF[11])
# Out:
# {'繳': 0.048723659799764715, '支': 0.05436448474979963, '成績': 0.043082834849729794, '連': 0.03433210734721176, '場': 0.021137117675791642, '比賽': 0.007950296237414988, '有安': 0.0351325386123148, '打創': 0.048723659799764715, '生涯': 0.0034122108623384196, '新高': 0.03433210734721176, '亞洲': 0.048723659799764715, '球星': 0.021541417424864897, '精華': 0.048723659799764715, '奧克蘭': 0.048723659799764715, '與': 0.013591121187449907, '洛杉磯': 0.0351325386123148, '天使': 0.03170567651368746, '系列': 0.048723659799764715, '賽首戰': 0.048723659799764715, '日籍': 0.021541417424864897, '好手': 0.01716605367360588, '擔任': 0.048723659799764715, '指定': 0.021541417424864897, '打擊': 0.007149864972311945, '棒': 0.01716605367360588, '並': 0.027182242374899815, '繳出': 0.027182242374899815, '吞': 0.048723659799764715, '同時': 0.01716605367360588, '創下': 0.048723659799764715, '有': 0.010568558837895821, '安打': 0.007950296237414988, '紀錄': 0.010568558837895821, '率': 0.010568558837895821, '也': 0.0034122108623384196, '上升': 0.048723659799764715, '至': 0
# ...
